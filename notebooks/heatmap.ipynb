# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = [
    [   -1, 0.050, 0.050, 0.050, 0.025],
    [0.050,    -1, 0.050, 0.050, 0.025],
    [0.025, 0.050,    -1, 0.050, 0.050],
    [0.050, 0.025, 0.050,    -1, 0.025],
    [0.025, 0.025, 0.025, 0.000,    -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [   -1, 0.250, 0.275, 0.250, 0.150],
    [0.250,    -1, 0.275, 0.225, 0.150],
    [0.225, 0.250,    -1, 0.275, 0.200],
    [0.250, 0.225, 0.275,    -1, 0.125],
    [0.125, 0.200, 0.175, 0.200,    -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [   -1, 0.500, 0.550, 0.500, 0.250],
    [0.500,    -1, 0.525, 0.475, 0.200],
    [0.500, 0.500,    -1, 0.525, 0.250],
    [0.500, 0.450, 0.550,    -1, 0.250],
    [0.250, 0.425, 0.325, 0.375,    -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [    -1, 9.2000, 20.000, 20.625, 12.725],
    [13.400,     -1, 20.625, 20.850, 12.725],
    [13.750, 10.725,     -1, 20.625, 12.750],
    [14.175, 9.8250, 20.925,     -1, 13.050],
    [13.525, 12.900, 10.250, 10.325,     -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [    -1, 63.850, 54.725, 64.500, 37.575],
    [63.200,     -1, 54.425, 64.000, 36.900],
    [63.800, 65.425,     -1, 65.675, 37.000],
    [62.125, 62.250, 57.000,     -1, 36.800],
    [41.975, 52.600, 36.075, 40.250,     -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [    -1, 73.575, 82.625, 81.225, 64.425],
    [77.850,     -1, 84.000, 82.850, 60.450],
    [78.825, 75.800,     -1, 86.400, 61.600],
    [78.075, 72.175, 85.175,     -1, 61.400],
    [52.400, 60.175, 58.400, 61.925,     -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >

# %%
arr = [
    [    -1, 0.6462, 0.6377, 0.6479, 0.7115],
    [0.7720,     -1, 0.7908, 0.7853, 0.7309],
    [0.7934, 0.7997,     -1, 0.7948, 0.7991],
    [0.7969, 0.8071, 0.8213,     -1, 0.8085],
    [0.6883, 0.6858, 0.6804, 0.6800,     -1],
]

index = ['Affe-Lang', 'Lang-Affe', 'Lang', 'Affe', 'nonCL']
columns = index

df = pd.DataFrame(arr, index, columns)
df

vmin = 0

sns.heatmap(df, annot=True, square=True, cmap='Blues', vmin=vmin)
# Out:
# <Axes: >
