# %%
from sklearn.cluster import KMeans

num_clusters = 8

kmeans_valaro = KMeans(n_clusters=num_clusters, random_state=0)
kmeans_token = KMeans(n_clusters=num_clusters, random_state=0)

# %%
import pandas as pd

df = pd.read_csv('./data/CL_expression_z64_bs512token_and_valaro.csv', header=None)
df
# Out:
#             0          1          2          3          4          5    \
# 0      9.239733 -13.238187  -7.655147  -2.086383  -2.928986  -6.403494
# 1      2.022734  -2.882744  -6.857207  -0.156795  -1.364711   0.726594
# 2      2.976880   7.346564  -7.828605   3.570187   1.800058   0.389140
# 3      4.181045  -9.818195 -11.207467  -0.310557  14.872347 -12.745742
# 4      8.753702  -0.767396  -5.359697   3.744622  -2.186875  -3.171172
# ...         ...        ...        ...        ...        ...        ...
# 3995   5.429466   2.609986  -6.702492   2.196674   1.837411  -6.488025
# 3996   8.843521  -3.946912  -6.594546   7.316992  21.229490  -4.040961
# 3997  11.804955  -0.286493  -3.750151   3.190089  10.490786  -4.585661
# 3998  14.139419  -4.056864 -10.065394  10.742180   8.129881   1.949528
# 3999  14.702228 -10.167955 -10.846167  -1.149657   5.374240  -5.238450
#
#             6         7          8         9    ...        760        761  \
# 0     -3.675484  0.870780  -2.094276 -5.337270  ...   9.733530   0.436622
# 1      1.405094  0.347463  -0.692743  0.069916  ...   5.658875  -4.147356
# 2      6.046457 -0.776226  -4.500265 -0.489320  ...   4.087373  -2.068028
# 3     -4.598417 -2.239102  -6.168123  9.145287  ...  20.428905 -23.855696
# 4      1.004965  1.594494  -5.195898  2.607379  ...   9.643133 -11.013873
# ...         ...       ...        ...       ...  ...        ...        ...
# 3995   3.205426 -4.449821  -0.325932 -2.663069  ...   7.454086  -2.055840
# 3996  -6.564354  6.451864  -5.244415 -4.836771  ...  18.981022  -4.553910
# 3997  -0.275093 -1.212365  -7.369063 -1.471068  ...  13.022439  -1.766573
# 3998   0.980052 -0.251444   0.021263  0.145167  ...  22.726906  -4.883986
# 3999 -13.277615  4.150430 -13.976494 -5.834514  ...  17.485149  -6.331582
#
#             762        763       764       765       766        767       768  \
# 0      1.768371  -1.285282 -4.179274  0.372269 -2.069253   1.934787 -0.653310
# 1     -0.634146  -1.360576  1.333844  1.493725 -1.066133   0.725842 -0.176846
# 2     -1.373302  -0.803734 -0.186786 -2.795310 -3.329384  -1.027990 -0.367789
# 3     -5.525981  11.853601  8.056058 -5.756880  0.725617  -3.377930 -0.062911
# 4      0.765451  -0.483979  6.236182  0.706542 -8.118749  -2.775182  0.004839
# ...         ...        ...       ...       ...       ...        ...       ...
# 3995   6.420737  -3.552339  1.586434  6.476898 -4.546366   5.183108  0.007937
# 3996  15.685933  -0.299793 -4.586097  0.772758  4.174127 -11.471359 -0.529100
# 3997   2.900292   0.735412  2.544002 -0.158271  6.576291  -3.434418 -0.301587
# 3998   5.919477   4.836126 -1.794853 -3.387551  6.134054   0.167126 -0.275842
# 3999   1.506216   5.300592  2.035488 -5.434203  5.221092  -6.825011 -0.667828
#
#            769
# 0     0.653310
# 1    -0.077640
# 2     0.183895
# 3     0.532327
# 4    -0.004839
# ...        ...
# 3995  0.007937
# 3996  0.707672
# 3997  0.238095
# 3998  0.590399
# 3999 -0.246806
#
# [4000 rows x 770 columns]

# %%
df_valaro = df.iloc[:, -2:]
df_token = df.iloc[:, :-2]

# %%
df_valaro
# Out:
#            768       769
# 0    -0.653310  0.653310
# 1    -0.176846 -0.077640
# 2    -0.367789  0.183895
# 3    -0.062911  0.532327
# 4     0.004839 -0.004839
# ...        ...       ...
# 3995  0.007937  0.007937
# 3996 -0.529100  0.707672
# 3997 -0.301587  0.238095
# 3998 -0.275842  0.590399
# 3999 -0.667828 -0.246806
#
# [4000 rows x 2 columns]

# %%
df_token
# Out:
#             0          1          2          3          4          5    \
# 0      9.239733 -13.238187  -7.655147  -2.086383  -2.928986  -6.403494
# 1      2.022734  -2.882744  -6.857207  -0.156795  -1.364711   0.726594
# 2      2.976880   7.346564  -7.828605   3.570187   1.800058   0.389140
# 3      4.181045  -9.818195 -11.207467  -0.310557  14.872347 -12.745742
# 4      8.753702  -0.767396  -5.359697   3.744622  -2.186875  -3.171172
# ...         ...        ...        ...        ...        ...        ...
# 3995   5.429466   2.609986  -6.702492   2.196674   1.837411  -6.488025
# 3996   8.843521  -3.946912  -6.594546   7.316992  21.229490  -4.040961
# 3997  11.804955  -0.286493  -3.750151   3.190089  10.490786  -4.585661
# 3998  14.139419  -4.056864 -10.065394  10.742180   8.129881   1.949528
# 3999  14.702228 -10.167955 -10.846167  -1.149657   5.374240  -5.238450
#
#             6         7          8         9    ...        758        759  \
# 0     -3.675484  0.870780  -2.094276 -5.337270  ...   6.101656 -20.038374
# 1      1.405094  0.347463  -0.692743  0.069916  ...   9.400425 -20.058701
# 2      6.046457 -0.776226  -4.500265 -0.489320  ...  -1.979857 -16.771322
# 3     -4.598417 -2.239102  -6.168123  9.145287  ...   1.519912 -64.590271
# 4      1.004965  1.594494  -5.195898  2.607379  ...   8.252132 -10.032241
# ...         ...       ...        ...       ...  ...        ...        ...
# 3995   3.205426 -4.449821  -0.325932 -2.663069  ...  10.849719 -19.800949
# 3996  -6.564354  6.451864  -5.244415 -4.836771  ...   6.922243 -65.449387
# 3997  -0.275093 -1.212365  -7.369063 -1.471068  ...   8.014185 -52.621574
# 3998   0.980052 -0.251444   0.021263  0.145167  ...   8.130757 -35.386307
# 3999 -13.277615  4.150430 -13.976494 -5.834514  ...   2.996067 -79.258904
#
#             760        761        762        763       764       765  \
# 0      9.733530   0.436622   1.768371  -1.285282 -4.179274  0.372269
# 1      5.658875  -4.147356  -0.634146  -1.360576  1.333844  1.493725
# 2      4.087373  -2.068028  -1.373302  -0.803734 -0.186786 -2.795310
# 3     20.428905 -23.855696  -5.525981  11.853601  8.056058 -5.756880
# 4      9.643133 -11.013873   0.765451  -0.483979  6.236182  0.706542
# ...         ...        ...        ...        ...       ...       ...
# 3995   7.454086  -2.055840   6.420737  -3.552339  1.586434  6.476898
# 3996  18.981022  -4.553910  15.685933  -0.299793 -4.586097  0.772758
# 3997  13.022439  -1.766573   2.900292   0.735412  2.544002 -0.158271
# 3998  22.726906  -4.883986   5.919477   4.836126 -1.794853 -3.387551
# 3999  17.485149  -6.331582   1.506216   5.300592  2.035488 -5.434203
#
#            766        767
# 0    -2.069253   1.934787
# 1    -1.066133   0.725842
# 2    -3.329384  -1.027990
# 3     0.725617  -3.377930
# 4    -8.118749  -2.775182
# ...        ...        ...
# 3995 -4.546366   5.183108
# 3996  4.174127 -11.471359
# 3997  6.576291  -3.434418
# 3998  6.134054   0.167126
# 3999  5.221092  -6.825011
#
# [4000 rows x 768 columns]

# %%
kmeans_valaro.fit(df_valaro)
kmeans_valaro.labels_
# Out:
# /home/rkn/.local/share/virtualenvs/AffectNet-experiments-e17pgDV_/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([4, 6, 5, ..., 5, 5, 2], dtype=int32)

# %%
kmeans_token.fit(df_token)
kmeans_token.labels_
# Out:
# /home/rkn/.local/share/virtualenvs/AffectNet-experiments-e17pgDV_/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([3, 0, 0, ..., 5, 5, 7], dtype=int32)

# %%
from itertools import permutations

def generate_combinations(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("Input lists must have the same length")
    
    n = len(list1)
    indices = list(range(n))
    combinations = []
    
    for perm in permutations(indices):
        combination = {list1[i]: list2[perm[i]] for i in range(n)}
        combinations.append(combination)
    
    return combinations

list1 = list(range(8))

combinations = generate_combinations(list1, list1)

print(len(combinations))

# for combination in combinations:
#     print(combination)
# Out:
# 40320

# %%
from tqdm import tqdm

indices = list(range(8))
kappa = -1
for c in tqdm(generate_combinations(indices, indices)):
    n_match = 0
    for n_samples, (valaro_cat, token_cat) in enumerate(zip(kmeans_valaro.labels_, kmeans_token.labels_)):
        if token_cat == c[valaro_cat]:
            n_match += 1
    score = n_match / (1 + n_samples)
    if score > kappa:
        kappa = score

print('score:', kappa)
# Out:
# 100%|██████████| 40320/40320 [03:56<00:00, 170.55it/s]
# score: 0.4185
