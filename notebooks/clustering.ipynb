# %%
from sklearn.cluster import KMeans

num_clusters = 8

kmeans_valaro = KMeans(n_clusters=num_clusters, random_state=0)
kmeans_token = KMeans(n_clusters=num_clusters, random_state=0)

# %%
import pandas as pd

df = pd.read_csv('./data/CL_landmark_z64_bs512token_and_valaro.csv', header=None)
df
# Out:
#            0         1          2          3         4         5         6    \
# 0     4.319646  3.552201  -1.456006   9.593410  8.228291 -1.046198 -4.262713
# 1    -1.286482 -2.213928  -5.331310   7.378739  3.413975  9.303810 -3.922620
# 2     2.213944  1.797968  -9.611431   9.844759  8.705488  1.938567  3.200283
# 3     6.607168  7.358271 -10.696171   3.724116  2.233982 -3.017179 -2.655783
# 4     4.008245  1.537030  -0.314131 -10.823812 -2.683642  2.027727  1.062453
# ...        ...       ...        ...        ...       ...       ...       ...
# 3995  5.028384  5.059798   0.711295   4.854717  1.460216  3.046557  0.827787
# 3996  7.047041  6.448936   8.143433   2.724073 -0.004817  5.679399 -1.554422
# 3997  7.219131  1.842679 -10.824577   7.046616  6.324637  3.618669 -3.837756
# 3998  1.712483  6.406160   0.941962  -4.661302 -7.823059  4.115626 -0.314636
# 3999  3.989721  5.252335   8.347409   5.744947  1.326700  1.218711 -6.749275
#
#            7         8         9    ...        760       761        762  \
# 0     0.044569  1.565159 -5.184818  ...  -1.452535  0.890580   7.764274
# 1    -1.759443  3.562086 -1.849271  ...  -1.057878  7.109754   0.555162
# 2    -0.189736 -0.564993 -3.953882  ...  -3.937334  1.640902  -0.846030
# 3    -1.314228 -1.557243  0.619743  ...   2.415100  4.102931   9.005374
# 4     5.804184  8.113216  4.593838  ...   5.869513  5.183249   2.509662
# ...        ...       ...       ...  ...        ...       ...        ...
# 3995 -2.692935 -2.417437  0.124362  ...   2.775624  2.492267   6.779849
# 3996  3.420306  2.186948  1.685361  ...   7.001081  7.185966  12.560402
# 3997  1.146881 -0.962852 -4.723722  ...  -3.589099  3.839083  -3.807260
# 3998  5.205226  3.918263  1.095679  ...  13.157889  3.026226  12.209599
# 3999 -0.153095 -1.222500 -1.348977  ...  -2.029268  5.337760   1.728460
#
#             763       764        765       766        767       768       769
# 0     -8.066551  2.604601   7.604827 -5.728002 -12.087186 -0.653310  0.653310
# 1     -1.884119  4.076912  13.303690 -6.916384  -7.437416 -0.176846 -0.077640
# 2     -5.276183  2.945396  -0.528675 -7.737108  -3.505105 -0.367789  0.183895
# 3      0.429731 -4.116433  -4.238285  3.390852  -5.763457 -0.062911  0.532327
# 4     -0.542688 -3.007723  -3.883421  3.169199   3.098373  0.004839 -0.004839
# 3997  1.146881 -0.962852 -4.723722  ...  5.895921 -59.341156  -3.589099
# 3998  5.205226  3.918263  1.095679  ...  7.491039 -81.963326  13.157889
# 3999 -0.153095 -1.222500 -1.348977  ... -1.646916 -66.427452  -2.029268
#
#            761        762        763       764        765       766        767
# 0     0.890580   7.764274  -8.066551  2.604601   7.604827 -5.728002 -12.087186
# 1     7.109754   0.555162  -1.884119  4.076912  13.303690 -6.916384  -7.437416
# 2     1.640902  -0.846030  -5.276183  2.945396  -0.528675 -7.737108  -3.505105
# 3     4.102931   9.005374   0.429731 -4.116433  -4.238285  3.390852  -5.763457
# 4     5.183249   2.509662  -0.542688 -3.007723  -3.883421  3.169199   3.098373
# ...        ...        ...        ...       ...        ...       ...        ...
# 3995  2.492267   6.779849   0.690414 -3.465382  -2.268770  3.295204  -1.460202
# 3996  7.185966  12.560402 -10.439320  4.964150  11.289249  4.767035 -12.504708
# 3997  3.839083  -3.807260  -2.713939  1.005645  -0.585341 -8.248549 -12.834028
# 3998  3.026226  12.209599  -4.264317 -2.015975  -5.387304  9.460820   1.903445
# 3999  5.337760   1.728460  -3.866306  5.516696  11.810710 -0.469411 -12.347671
#
# [4000 rows x 768 columns]

# %%
kmeans_valaro.fit(df_valaro)
kmeans_valaro.labels_
# Out:
# /home/rkn/.local/share/virtualenvs/AffectNet-experiments-e17pgDV_/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([4, 6, 5, ..., 5, 5, 2], dtype=int32)

# %%
kmeans_token.fit(df_token)
kmeans_token.labels_
# Out:
# /home/rkn/.local/share/virtualenvs/AffectNet-experiments-e17pgDV_/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([3, 6, 3, ..., 3, 7, 3], dtype=int32)

# %%
from itertools import permutations

def generate_combinations(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("Input lists must have the same length")
    
    n = len(list1)
    indices = list(range(n))
    combinations = []
    
    for perm in permutations(indices):
        combination = {list1[i]: list2[perm[i]] for i in range(n)}
        combinations.append(combination)
    
    return combinations

list1 = list(range(8))

combinations = generate_combinations(list1, list1)

print(len(combinations))

# for combination in combinations:
#     print(combination)
# Out:
# 40320

# %%
from tqdm import tqdm

indices = list(range(8))
kappa = -1
for c in tqdm(generate_combinations(indices, indices)):
    n_match = 0
    for n_samples, (valaro_cat, token_cat) in enumerate(zip(kmeans_valaro.labels_, kmeans_token.labels_)):
        if token_cat == c[valaro_cat]:
            n_match += 1
    score = n_match / (1 + n_samples)
    if score > kappa:
        kappa = score

print('score:', kappa)
# Out:
# 100%|██████████| 40320/40320 [03:55<00:00, 171.02it/s]
# score: 0.191
